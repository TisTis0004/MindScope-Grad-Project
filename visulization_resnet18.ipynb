# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# acc= pd.read_csv('visulization resnet18/acc.csv')
f1=pd.read_csv('visulization resnet18/f1.csv')
loss=pd.read_csv('visulization resnet18/loss.csv')
# pr_auc=pd.read_csv('visulization resnet18/pr_auc.csv')
recall=pd.read_csv('visulization resnet18/recall.csv')
# roc_auc=pd.read_csv('visulization resnet18/roc_auc.csv')
# precision=pd.read_csv('visulization resnet18/precision.csv')

# %%
roc_auc.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 roc_auc.head()
#
# NameError: name 'roc_auc' is not defined

# %%
plt.plot(acc['Step'] , acc['Value'] ,color='red')
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'black','size':15}
plt.title('Accuarcy plot', fontdict=font1)
plt.xlabel('epochs', fontdict=font2)
plt.ylabel('Value' ,  fontdict=font2)
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.plot(f1['Step'] , f1['Value'] ,color='red')
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'black','size':15}
plt.title('F1 Score_resnet18', fontdict=font1)
plt.xlabel('epochs', fontdict=font2)
plt.ylabel('Value' ,  fontdict=font2)
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.plot(loss['Step'] , loss['Value'] ,color='red')
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'black','size':15}
plt.title('Loss_resnet18', fontdict=font1)
plt.xlabel('epochs', fontdict=font2)
plt.ylabel('Value' ,  fontdict=font2)
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.plot(pr_auc['Step'] , pr_auc['Value'] ,color='red')
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'black','size':15}
plt.title('pr_auc', fontdict=font1)
plt.xlabel('epochs', fontdict=font2)
plt.ylabel('Value' ,  fontdict=font2)
#It ignores how well you handle the "Negative" class (since there are too many of them) and focuses entirely on how well you find the "Positive" class.
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.plot(precision['Step'] , precision['Value'] ,color='red')
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'black','size':15}
plt.title('precision', fontdict=font1)
plt.xlabel('epochs', fontdict=font2)
plt.ylabel('Value' ,  fontdict=font2)
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.plot(recall['Step'] , recall['Value'] ,color='red')
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'black','size':15}
plt.title('recall_resnet18', fontdict=font1)
plt.xlabel('epochs', fontdict=font2)
plt.ylabel('Value' ,  fontdict=font2)
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.plot(roc_auc['Step'] , roc_auc['Value'] ,color='red')
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'black','size':15}
plt.title('roc_auc', fontdict=font1)
plt.xlabel('epochs', fontdict=font2)
plt.ylabel('Value' ,  fontdict=font2)
#The Goal: It measures how well the model separates the "Positive" class from the "Negative" class.
# Out:
# Text(0, 0.5, 'Value')
